# %%
import random
choices = ["Starving", "Hungry", "Snack"]
time_choices = ["Morning", "Afternoon", "Night"]
hunger = input("Are you 'Starving', 'Hungry', or Want a 'snack'?: ")
time = input("What time of the day is it 'Morning', 'Afternoon', 'Night'?: ")
hunger = hunger.capitalize()
time = time.capitalize()
choice=[]
#all starving must have takeout, reservations, or delivery. Quick and fast.  

starving_morning = ["Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039",
"Funk 'n Waffles: 727 S Crouse Ave Ste 8, Syracuse, NY 13210",
"Stella's Diner: 110 Wolf St, Syracuse, NY 13208", "Cheesecake Factory: 306 Hiawatha Blvd W J-112, Syracuse, NY 13290"]

starving_afternoon =["Stella's Diner: 110 Wolf St, Syracuse, NY 13208",
                     "Chipotle Mexican Grill: 129 Marshall St, Syracuse, NY 13210",
                    "Bleu Monkey Cafe: 163 Marshall St, Syracuse, NY 13210",
                     "Dinosaur Bar-B-Que: 246 W Willow St, Syracuse, NY 13202",
                    "Varsity Pizza: 802 S Crouse Ave Syracuse, Ny 13210",
                     "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039",
                    "Chipotle Mexican Grill: 129 Marshall St, Syracuse, NY 13210",
                    "Phoebe's Restaurant & Coffee Lounge: 900 E Genesee St, Syracuse, NY 13210",
                    "Panda West Chinese Restaurant: 135 Marshall St, Syracuse, NY 13210",
                    "Calios: 123 Marshall St, Syracuse, NY 13210",
                    "Cheesecake Factory: 306 Hiawatha Blvd W J-112, Syracuse, NY 13290"]

starving_night = ["Chipotle Mexican Grill: 129 Marshall St, Syracuse, NY 13210",
                 "Bleu Monkey Cafe: 163 Marshall St, Syracuse, NY 13210",
                  "Dinosaur Bar-B-Que: 246 W Willow St, Syracuse, NY 13202",
                 "Varsity Pizza: 802 S Crouse Ave Syracuse, Ny 13210",
                 "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039",
                 "Lemon Grass Restaurant: 238 W Jefferson St",
                 "Chipotle Mexican Grill: 129 Marshall St, Syracuse, NY 13210",
                 "Pastabilities: 311 S Franklin St Syracuse, Ny 13202",
                 "Phoebe's Restaurant & Coffee Lounge: 900 E Genesee St, Syracuse, NY 13210",
                  "Panda West Chinese Restaurant: 135 Marshall St, Syracuse, NY 13210",
                 "Calios: 123 Marshall St, Syracuse, NY 13210",
                 "Cheesecake Factory: 306 Hiawatha Blvd W J-112, Syracuse, NY 13290"]


#all hungry can be anything as long as it fits in the morning, after, night categories
hungry_morning = ["Original Grain: 302 S Salina St, Syracuse, NY 13202",
                 "Mom's Diner: 501 Westcott St, Syracuse, NY 13210",
                 "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039",
                 "Stella's Diner: 110 Wolf St, Syracuse, NY 13208",
                 "Cheesecake Factory: 306 Hiawatha Blvd W J-112, Syracuse, NY 13290"]

hungry_afternoon = ["Varsity Pizza: 802 S Crouse Ave Syracuse, Ny 13210",
                   "Mom's Diner: 501 Westcott St, Syracuse, NY 13210",
                   "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039",
             "Salt City Coffee: 509 W Onondaga St, Syracuse, NY 13204"]

             
                    
if(hunger in choices and time in time_choices):
    
    if(hunger == 'Starving' and time == 'Morning'):
        choice = random.choice(starving_morning)
        print(choice)
    elif(hunger == 'Starving' and time == 'Afternoon'):
        choice = random.choice(starving_afternoon)
        print(choice)
    elif(hunger == 'Starving' and time == 'Night'):
        choice = random.choice(starving_night)
        print(choice)
    elif(hunger == 'Hungry' and time == 'Morning'):
        choice = random.choice(hungry_morning)
        print(choice)
    elif(hunger == 'Hungry' and time == 'Afternoon'):
        choice = random.choice(hungry_afternoon)
        print(choice)
    elif(hunger == 'Hungry' and time == 'Night'):
        choice = random.choice(hungry_night)
        print(choice)
    elif(hunger == 'Snack' and time == 'Morning'):
        choice = random.choice(snack_morning)
        print(choice)
    elif(hunger == 'Snack' and time == 'Afternoon'):
        choice = random.choice(snack_afternoon)
        print(choice)
    elif(hunger == 'Snack' and time == 'Night'):
        choice = random.choice(snack_night)
        print(choice)
        
else:
    print("That is not a correct term for your hungriness")
    print("You must enter Morning, Afternoon, or Night")
# Out:
# Are you 'Starving', 'Hungry', or Want a 'snack'?: STarving
# What time of the day is it 'Morning', 'Afternoon', 'Night'?: Morning
# Cheesecake Factory: 306 Hiawatha Blvd W J-112, Syracuse, NY 13290

# %%
import folium
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
SYR = (43.0481, -76.1474)
map = folium.Map(location=SYR, zoom_start=14)
directions = pd.read_csv('latlong.csv') #, dtype = {'Longitude': object})
if directions['Restaurants: Address'] == choice:
        pos = (column['Latitude'],column['Longitude'])
        marker = folium.Marker(location=pos)
        map.add_children(marker)
map
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-0c3c2b1edc8d> in <module>()
#       7 map = folium.Map(location=SYR, zoom_start=14)
#       8 directions = pd.read_csv('latlong.csv') #, dtype = {'Longitude': object})
# ----> 9 if directions['Restaurants'] == choice:
#      10         pos = (column['Latitude'],column['Longitude'])
#      11         marker = folium.Marker(location=pos)
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1119         raise ValueError("The truth value of a {0} is ambiguous. "
#    1120                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1121                          .format(self.__class__.__name__))
#    1122
#    1123     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import folium
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import IPython.display
SYR = (43.0481, -76.1474)
map = folium.Map(location=SYR, zoom_start=14)
directions = pd.read_csv('latlong.csv') #, dtype = {'Longitude': object})
directions[ ['Latitude','Longitude']]

for d in directions.to_records():
    pos = (d['Latitude'],d['Longitude'])
    message = "Restaurant: %s. Address: %s" % (d['Restaurants'],d['Address'])
    marker = folium.Marker(location=pos, popup=message)
    map.add_children(marker)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
res = pd.DataFrame(directions.sample()['Restaurants'])
res

for item in res:
    if item == choice:
        pd.DataFrame(directions.sample()['Restaurants'])
        print(item)

# %%
res = pd.DataFrame(directions.sample()['Restaurants'])
res
# Out:
#          Restaurants
# 21  Salt City Coffee

# %%
directions
# Out:
#                             Restaurants  \
# 0                           Chick-fil-a
# 1                       Funk 'n Waffles
# 2                        Stella's Diner
# 3                    Cheesecake Factory
# 4                Chipotle Mexican Grill
# 5                      Bleu Monkey Cafe
# 6                    Dinosaur Bar-B-Que
# 7                         Varsity Pizza
# 8   Phoebe's Restaurant & Coffee Lounge
# 9         Panda West Chinese Restaurant
# 10                               Calios
# 11               Lemon Grass Restaurant
# 12                        Pastabilities
# 13                       Original Grain
# 14                          Mom's Diner
# 15                           Cafe Kubal
# 16                            Starbucks
# 17                            Starbucks
# 18                       Dunkin' Donuts
# 19                        Recess Coffee
# 20                     The Sweet Praxis
# 21                     Salt City Coffee
# 22                     Unique Tea House
# 23                     Insomnia Cookies
#
#                                         Address   Latitude  Longitude  \
# 0             7916 Brewerton Rd Cicero NY 13039  43.153199 -76.123188
# 1      727 S Crouse Ave Ste 8 Syracuse NY 13210  43.042119 -76.136118
# 2                 110 Wolf St Syracuse NY 13208  43.069115 -76.165286
# 3    306 Hiawatha Blvd W J-11 Syracuse NY 13290  43.069270 -76.171220
# 4             129 Marshall St Syracuse NY 13210  43.041790 -76.135965
# 5             163 Marshall St Syracuse NY 13210  43.041775 -76.135236
# 6             246 W Willow St Syracuse NY 13202  43.052687 -76.154598
# 7            802 S Crouse Ave Syracuse Ny 13210  43.041475 -76.136938
# 8            900 E Genesee St Syracuse NY 13210  43.046700 -76.137585
# 9             135 Marshall St Syracuse NY 13210  43.041855 -76.135718
# 10            123 Marshall St Syracuse NY 13210  43.041768 -76.136113
# 11                           238 W Jefferson St  43.047553 -76.154419
# 12          311 S Franklin St Syracuse Ny 13202  43.048302 -76.155406
# 13            302 S Salina St Syracuse NY 13202  43.048509 -76.152504
# 14            501 Westcott St Syracuse NY 13210  43.041390 -76.119061
# 15         720 University Ave Syracuse NY 13210  43.042265 -76.134613
# 16            177 Marshall St Syracuse NY 13210  43.041746 -76.134625
# 17               150 Henry St Syracuse NY 13210  43.036579 -76.141100
# 18           746 S Crouse Ave Syracuse NY 13210  43.041641 -76.136842
# 19     110 Montgomery St #103 Syracuse NY 13202  43.050052 -76.149458
# 20             203 E Water St Syracuse NY 13202  43.050716 -76.150612
# 21          509 W Onondaga St Syracuse NY 13204  43.039516 -76.158300
# 22            171 Marshall St Syracuse NY 13210  43.041807 -76.134908
# 23            137 Marshall St Syracuse NY 13210  43.041727 -76.135656
#
#                           City
# 0                        Cicero
# 1                      Syracuse
# 2                      Syracuse
# 3                      Syracuse
# 4                      Syracuse
# 5            Syracuse
# 6    Syracuse
# 7                      Syracuse
# 8              Syracuse
# 9                      Syracuse
# 10                     Syracuse
# 11                     Syracuse
# 12                     Syracuse
# 13                     Syracuse
# 14                     Syracuse
# 15                     Syracuse
# 16              Syracuse
# 17                     Syracuse
# 18                     Syracuse
# 19                   Syracuse
# 20                     Syracuse
# 21                     Syracuse
# 22                     Syracuse
# 23                     Syracuse
