# %%
if random.choice(starving_morning) == "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039":
    print()
elif random.choice(starving_morning) == "Funk 'n Waffles: 727 S Crouse Ave Ste 8, Syracuse, NY 13210":
    print()
elif random.choice(starving_morning) == "Stella's Diner: 110 Wolf St, Syracuse, NY 13208":
    print()
elif random.choice(starving_morning) == "Cheesecake Factory: 306 Hiawatha Blvd W J-112, Syracuse, NY 13290":
    print()
#starving lunch if statements
if random.choice(starving_afternoon) == "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039":
    print()
elif random.choice(starving_afternoon) == "Stella's Diner: 110 Wolf St, Syracuse, NY 13208":
    print()
elif random.choice(starving_afternoon) =="Chipotle Mexican Grill: 129 Marshall St, Syracuse, NY 13210" :
    print()
elif random.choice(starving_afternoon) =="Dinosaur Bar-B-Que: 246 W Willow St, Syracuse, NY 13202":
    print()
elif random.choice(starving_afternoon) =="Varsity Pizza: 802 S Crouse Ave Syracuse, Ny 13210":
    print()
elif random.choice(starving_afternoon) =="Phoebe's Restaurant & Coffee Lounge: 900 E Genesee St, Syracuse, NY 13210":
    print()
elif random.choice(starving_afternoon) =="Panda West Chinese Restaurant: 135 Marshall St, Syracuse, NY 13210":
    print()
elif random.choice(starving_afternoon) =="Calios: 123 Marshall St, Syracuse, NY 13210":
    print()
elif random.choice(starving_afternoon) =="Cheesecake Factory: 306 Hiawatha Blvd W J-112, Syracuse, NY 13290":
    print()
elif random.choice(starving_afternoon) =="Bleu Monkey Cafe: 163 Marshall St, Syracuse, NY 13210":
    print()    
#starving night if statements
if random.choice(starving_night) =="Chipotle Mexican Grill: 129 Marshall St, Syracuse, NY 13210" :
    print()
elif random.choice(starving_night) == "Bleu Monkey Cafe: 163 Marshall St, Syracuse, NY 13210" :
    print()
elif random.choice(starving_night) == "Dinosaur Bar-B-Que: 246 W Willow St, Syracuse, NY 13202" :
    print()
elif random.choice(starving_night) == "Varsity Pizza: 802 S Crouse Ave Syracuse, Ny 13210"  :
    print()
elif random.choice(starving_night) == "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039"  :
    print()
elif random.choice(starving_night) == "Lemon Grass Restaurant: 238 W Jefferson St" :
    print()
elif random.choice(starving_night) == "Pastabilities: 311 S Franklin St Syracuse, Ny 13202"  :
    print()
elif random.choice(starving_night) == "Phoebe's Restaurant & Coffee Lounge: 900 E Genesee St, Syracuse, NY 13210":
    print()
elif random.choice(starving_night) == "Panda West Chinese Restaurant: 135 Marshall St, Syracuse, NY 13210" :
    print()
elif random.choice(starving_night) =="Calios: 123 Marshall St, Syracuse, NY 13210":
    print()
elif random.choice(starving_night) =="Cheesecake Factory: 306 Hiawatha Blvd W J-112, Syracuse, NY 13290":
    print()

# %%
if random.choice(hungry_morning) == "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039":
    print('')
elif random.choice(hungry_morning) == "Original Grain: 302 S Salina St, Syracuse, NY 13202":
    print('')
elif random.choice(hungry_morning) == "Mom's Diner: 501 Westcott St, Syracuse, NY 13210":
    print('')
elif random.choice(hungry_morning) == "Stella's Diner: 110 Wolf St, Syracuse, NY 13208":
    print('')
elif random.choice(hungry_morning) == "Cheesecake Factory: 306 Hiawatha Blvd W J-112, Syracuse, NY 13290":
    print('')
if random.choice(hungry_afternoon) == "Varsity Pizza: 802 S Crouse Ave Syracuse, Ny 13210":
    print('')
elif random.choice(hungry_afternoon) == "Mom's Diner: 501 Westcott St, Syracuse, NY 13210":
    print('')
elif random.choice(hungry_afternoon) == "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039":
    print('')
elif random.choice(hungry_afternoon) == "Stella's Diner: 110 Wolf St, Syracuse, NY 13208":
    print('')
elif random.choice(hungry_afternoon) == "Chipotle Mexican Grill: 129 Marshall St, Syracuse, NY 1321":
    print('')
elif random.choice(hungry_afternoon) == "Bleu Monkey Cafe: 163 Marshall St, Syracuse, NY 13210":
    print('')
elif random.choice(hungry_afternoon) == "Dinosaur Bar-B-Que:246 W Willow St, Syracuse, NY 13202":
    print('')
elif random.choice(hungry_afternoon) == "Phoebe's Restaurant & Coffee Lounge: 900 E Genesee St, Syracuse, NY 13210":
    print('')
elif random.choice(hungry_afternoon) == "Panda West Chinese Restaurant: 135 Marshall St, Syracuse, NY 13210":
    print('')
elif random.choice(hungry_afternoon) == "Calios: 123 Marshall St, Syracuse, NY 13210":
    print('')
elif random.choice(hungry_afternoon) == "Cheesecake Factory: 306 Hiawatha Blvd W J-112, Syracuse, NY 13290":
    print('')
if random.choice(hungry_night) == "Cheesecake Factory: 306 Hiawatha Blvd W J-112, Syracuse, NY 13290":
    print('')
elif random.choice(hungry_night) == "Dinosaur Bar-B-Que:246 W Willow St, Syracuse, NY 13202":
    print('')
if random.choice(hungry_night) == "Varsity Pizza: 802 S Crouse Ave Syracuse, Ny 13210":
    print('')
if random.choice(hungry_night) == "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039":
    print('')
elif random.choice(hungry_night) == "Bleu Monkey Cafe: 163 Marshall St, Syracuse, NY 13210":
    print('')
elif random.choice(hungry_night) == "Chipotle Mexican Grill: 129 Marshall St, Syracuse, NY 1321":
    print('')
elif random.choice(hungry_night) == "Panda West Chinese Restaurant: 135 Marshall St, Syracuse, NY 13210":
    print('')
elif random.choice(hungry_night) == "Cheesecake Factory: 306 Hiawatha Blvd W J-112, Syracuse, NY 13290":
    print()
elif random.choice(hungry_night) == "Calios: 123 Marshall St, Syracuse, NY 13210":
    print()
elif random.choice(hungry_night) == "Lemon Grass Restaurant: 238 W Jefferson":
    print()
elif random.choice(hungry_night) == “Pastabilities: 311 S Franklin St Syracuse, Ny 13202":
    print()
elif random.choice(hungry_night) == "Phoebe's Restaurant & Coffee Lounge: 900 E Genesee St, Syracuse, NY 13210":
    print()

# %%
if random.choice(snack_morning) == "Cafe Kubal: 720 University Ave, Syracuse, NY 13210":
    print()
elif random.choice(snack_morning) == "Starbucks: 177 Marshall St, Syracuse, NY 13210":
    print()
elif random.choice(snack_morning) == "Starbucks: 150 Henry St, Syracuse, NY 13210":
    print()
elif random.choice(snack_morning) == "Original Grain: 302 S Salina St, Syracuse, NY 13202":
    print()
elif random.choice(snack_morning) == "Dunkin' Donuts: 746 S Crouse Ave, Syracuse, NY 13210":
    print()
elif random.choice(snack_morning) == "Recess Coffee: 110 Montgomery St #103, Syracuse, NY 13202":
    print()
elif random.choice(snack_morning) == "The Sweet Praxis: 203 E Water St, Syracuse, NY 13202":
    print()
elif random.choice(snack_morning) == "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039":
    print()
elif random.choice(snack_morning) == "Salt City Coffee: 509 W Onondaga St, Syracuse, NY 13204":
    print()
if random.choice(snack_afternoon) == "Unique Tea House: 171 Marshall St, Syracuse, NY 13210":
    print()
elif random.choice(snack_afternoon) == "Insomnia Cookies: 137 Marshall St, Syracuse, NY 13210":
    print()
elif random.choice(snack_afternoon) == "Starbucks: 177 Marshall St, Syracuse, NY 13210":
    print()
elif random.choice(snack_afternoon) == "Starbucks: 150 Henry St, Syracuse, NY 13210":
    print()
elif random.choice(snack_afternoon) == "Original Grain: 302 S Salina St, Syracuse, NY 13202":
    print()
elif random.choice(snack_afternoon) == "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039":
    print()
elif random.choice(snack_afternoon) == "Salt City Coffee: 509 W Onondaga St, Syracuse, NY 13204":
    print()
if random.choice(snack_night) == "Unique Tea House: 171 Marshall St, Syracuse, NY 13210":
    print()
elif random.choice(snack_night) == "Insomnia Cookies: 137 Marshall St, Syracuse, NY 13210":
    print()
elif random.choice(snack_night) == "Starbucks: 177 Marshall St, Syracuse, NY 13210":
    print()
elif random.choice(snack_night) == "Starbucks: 150 Henry St, Syracuse, NY 13210":
    print()
elif random.choice(snack_night) == "Original Grain: 302 S Salina St, Syracuse, NY 13202":
    print()
elif random.choice(snack_night) == "Chick-fil-a: 7916 Brewerton Rd, Cicero, NY 13039":
    print()
elif random.choice(snack_night) == "Salt City Coffee: 509 W Onondaga St, Syracuse, NY 13204":
    print()
